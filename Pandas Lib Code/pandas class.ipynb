# %%
                                       # 12-11-2025  by vikas sir

# %%
import numpy as np
import pandas as pd

# %%
# Series

# %%
ar = np.array([12,3,4,5,7,85])
ls = [1,2,3,4,54]
pd.Series(ar)   # series generated by array
pd.Series(ls)   # series generated by list
# Out:
# 0     1
# 1     2
# 2     3
# 3     4
# 4    54
# dtype: int64

# %%
t = (2,3,4,5,6,7)
pd.Series(t)
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
dic = {'56,67}
# Out:
# name       [t, u, s]
# age     [34, 56, 67]
# dtype: object

# %%
# 13-11-2025

# %%
-------  Attributes

# %%
a = [23,4,56,87,67,65,67]
a1 = pd.Series(a,name= 'name')

# %%
a1.size
# Out:
# 7

# %%
a1.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
a1.dtype
# Out:
# dtype('int64')

# %%
a1.name
# Out:
# 'name'

# %%
a1.is_unique
# Out:
# False

# %%
a1.values
# Out:
# array([23,  4, 56, 87, 67, 65, 67], dtype=int64)

# %%
# 14-11-2025

# %%
# Method of series

a = [12,3,4,5,9,7,87,6,5]
a1 = pd.Series(a)

# %%
# head
a1.head()
# Out:
# 0    12
# 1     3
# 2     4
# 3     5
# 4     9
# dtype: int64

# %%
a1.head(2)
# Out:
# 0    12
# 1     3
# dtype: int64

# %%
# tail
a1.tail()
# Out:
# 4     9
# 5     7
# 6    87
# 7     6
# 8     5
# dtype: int64

# %%
# value_counts
a1.value_counts()
# Out:
# 5     2
# 12    1
# 3     1
# 4     1
# 9     1
# 7     1
# 87    1
# 6     1
# Name: count, dtype: int64

# %%
# sort_values
a1.sort_values()
# Out:
# 1     3
# 2     4
# 3     5
# 8     5
# 7     6
# 5     7
# 4     9
# 0    12
# 6    87
# dtype: int64

# %%
a1.sort_values(ascending = False)
# Out:
# 6    87
# 0    12
# 4     9
# 5     7
# 7     6
# 3     5
# 8     5
# 2     4
# 1     3
# dtype: int64

# %%
# sort_index
a1.sort_index()
# Out:
# 0    12
# 1     3
# 2     4
# 3     5
# 4     9
# 5     7
# 6    87
# 7     6
# 8     5
# dtype: int64

# %%
a1.sort_index(ascending = False)
# Out:
# 8     5
# 7     6
# 6    87
# 5     7
# 4     9
# 3     5
# 2     4
# 1     3
# 0    12
# dtype: int64

# %%
# chaining method 

b = [12,3,4,5,9,7,87,6,5]
b1 = pd.Series(b)

# %%
print(b1.sort_values().head(1).values[0])
# Out:
# 3

# %%
# customized index

# %%
Score = [23,56,87,98,98]
Name=['a','b','c','d','e']

s = pd.Series(Score,index = Name)
s
# Out:
# a    23
# b    56
# c    87
# d    98
# e    98
# dtype: int64

# %%
                                                 # 17-11-2025

# %%
# fancing indexing

# %%
# null variation

a = [23,56,np.nan,87,np.nan,88,np.nan,98,78]
ase = pd.Series(a)
# is null
ase.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8    False
# dtype: bool

# %%
# not null
ase.notnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8     True
# dtype: bool

# %%
# has nan ---------- ir is an atribute
ase.hasnans
# Out:
# True

# %%
#uniue
ase.unique()
# Out:
# array([23., 56., nan, 87., 88., 98., 78.])

# %%
# nuniue   --- not include the nan  value
ase.nunique()
# Out:
# 6
