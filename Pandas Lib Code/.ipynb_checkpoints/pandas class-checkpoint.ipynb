# %%
                                       # 12-11-2025  by vikas sir

# %%
import numpy as np
import pandas as pd

# %%
# Series

# %%
ar = np.array([12,3,4,5,7,85])
ls = [1,2,3,4,54]
pd.Series(ar)   # series generated by array
pd.Series(ls)   # series generated by list
# Out:
# 0     1
# 1     2
# 2     3
# 3     4
# 4    54
# dtype: int64

# %%
t = (2,3,4,5,6,7)
pd.Series(t)
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
dic = {'56,67}
# Out:
# name       [t, u, s]
# age     [34, 56, 67]
# dtype: object

# %%
# 13-11-2025

# %%
-------  Attributes

# %%
a = [23,4,56,87,67,65,67]
a1 = pd.Series(a,name= 'name')

# %%
a1.size
# Out:
# 7

# %%
a1.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
a1.dtype
# Out:
# dtype('int64')

# %%
a1.name
# Out:
# 'name'

# %%
a1.is_unique
# Out:
# False

# %%
a1.values
# Out:
# array([23,  4, 56, 87, 67, 65, 67], dtype=int64)

# %%
# 14-11-2025

# %%
# Method of series

a = [12,3,4,5,9,7,87,6,5]
a1 = pd.Series(a)

# %%
# head
a1.head()
# Out:
# 0    12
# 1     3
# 2     4
# 3     5
# 4     9
# dtype: int64

# %%
a1.head(2)
# Out:
# 0    12
# 1     3
# dtype: int64

# %%
# tail
a1.tail()
# Out:
# 4     9
# 5     7
# 6    87
# 7     6
# 8     5
# dtype: int64

# %%
# value_counts
a1.value_counts()
# Out:
# 5     2
# 12    1
# 3     1
# 4     1
# 9     1
# 7     1
# 87    1
# 6     1
# Name: count, dtype: int64

# %%
# sort_values
a1.sort_values()
# Out:
# 1     3
# 2     4
# 3     5
# 8     5
# 7     6
# 5     7
# 4     9
# 0    12
# 6    87
# dtype: int64

# %%
a1.sort_values(ascending = False)
# Out:
# 6    87
# 0    12
# 4     9
# 5     7
# 7     6
# 3     5
# 8     5
# 2     4
# 1     3
# dtype: int64

# %%
# sort_index
a1.sort_index()
# Out:
# 0    12
# 1     3
# 2     4
# 3     5
# 4     9
# 5     7
# 6    87
# 7     6
# 8     5
# dtype: int64

# %%
a1.sort_index(ascending = False)
# Out:
# 8     5
# 7     6
# 6    87
# 5     7
# 4     9
# 3     5
# 2     4
# 1     3
# 0    12
# dtype: int64

# %%
# chaining method 

b = [12,3,4,5,9,7,87,6,5]
b1 = pd.Series(b)

# %%
print(b1.sort_values().head(1).values[0])
# Out:
# 3

# %%
# customized index

# %%
Score = [23,56,87,98,98]
Name=['a','b','c','d','e']

s = pd.Series(Score,index = Name)
s
# Out:
# a    23
# b    56
# c    87
# d    98
# e    98
# dtype: int64

# %%
                                                 # 17-11-2025

# %%
# fancing indexing

# %%
# null variation

a = [23,56,np.nan,87,np.nan,88,np.nan,98,78]
ase = pd.Series(a)
# is null
ase.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8    False
# dtype: bool

# %%
# not null
ase.notnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8     True
# dtype: bool

# %%
# has nan ---------- ir is an atribute
ase.hasnans
# Out:
# True

# %%
#uniue
ase.unique()
# Out:
# array([23., 56., nan, 87., 88., 98., 78.])

# %%
# nuniue   --- not include the nan  value
ase.nunique()
# Out:
# 6

# %%
#                                          20-11-2025

# %%
# dataframe

# %%
#read

df = pd.read_csv(r"C:\Users\HP\Downloads\government_data_science_opportunities.csv")

# %%
df
# Out:
#                                          Organization  \
# 0           Indian Space Research Organisation (ISRO)
# 1   Defence Research & Development Organisation (D...
# 2                         Reserve Bank of India (RBI)
# 3                   National Informatics Centre (NIC)
# 4           Indian Council of Medical Research (ICMR)
# 5                           Digital India Corporation
# 6                    Geological Survey of India (GSI)
# 7                  Indian Statistical Institute (ISI)
# 8                                        Invest India
# 9                      Ministry of Statistics (MoSPI)
# 10             Translational Health Science Institute
# 11                          Various State Governments
# 12                  Public Sector Undertakings (PSUs)
# 13                Central Adoption Resource Authority
#
#                                  Common_Positions  \
# 0           Scientist/Engineer SC, Data Scientist
# 1   Research Associate, Scientist B, Data Analyst
# 2         Data Scientist, Data Analyst, Economist
# 3       Scientist B, Data Analyst, System Analyst
# 4        Project Research Scientist, Data Manager
# 5           Data Scientist, Senior Data Scientist
# 6       Data Scientist, Geoinformatics Specialist
# 7               Statistical Officer, Data Analyst
# 8                  Data Analyst, Research Analyst
# 9                   Statistical Officer, JSO, SSO
# 10            Data Scientist, Computer Programmer
# 11                    Data Analyst, MIS Executive
# 12               Data Engineer, Technical Officer
# 13               Data Analyst, Assistant Director
#
#                            Entry_Requirements Approximate_Salary_Range  \
# 0                ME/MTech/MSc, GATE/ICRB Exam      ₹56,000 - ₹1,77,000
# 1               BE/BTech/ME/MTech, GATE Score      ₹56,000 - ₹1,77,000
# 2   Graduate/Postgraduate, Direct Recruitment      ₹40,000 - ₹1,50,000
# 3              BE/BTech/MCA, GATE/NIELIT Exam      ₹44,900 - ₹1,42,000
# 4                   PhD/MSc in relevant field      ₹35,000 - ₹1,00,000
# 5            BE/BTech/MSc, Direct Application      ₹50,000 - ₹1,25,000
# 6            MSc/MTech Geology/Earth Sciences      ₹56,000 - ₹1,77,000
# 7        MSc Statistics/Mathematics, UPSC ISS      ₹44,900 - ₹1,42,000
# 8           Graduate with 2+ years experience        ₹40,000 - ₹50,000
# 9               MSc Statistics, UPSC ISS Exam      ₹44,900 - ₹1,42,000
# 10            MSc/MTech/PhD in relevant field        ₹40,000 - ₹80,000
# 11           Graduate/Postgraduate, State PSC        ₹25,000 - ₹70,000
# 12                       BE/BTech, GATE Score      ₹50,000 - ₹1,50,000
# 13          Graduate with relevant experience        ₹40,000 - ₹70,000
#
#                                        Key_Benefits
# 0    Research opportunities, International projects
# 1    Defense technology, National security projects
# 2         Financial sector expertise, Policy making
# 3             Digital governance, IT infrastructure
# 4        Healthcare research, Medical data analysis
# 5            AI/ML initiatives, Innovation projects
# 6           Mineral exploration, Environmental data
# 7          Statistical research, Survey methodology
# 8          Investment promotion, Business analytics
# 9             National statistics, Economic surveys
# 10           Biomedical research, Health technology
# 11        Local governance, Public service delivery
# 12  Industrial projects, Infrastructure development
# 13           Child welfare, Social impact analytics

# %%
df.size
# Out:
# 70
